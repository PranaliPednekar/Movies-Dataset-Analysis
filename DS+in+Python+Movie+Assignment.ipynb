# %% [markdown]
# # Movies Assignment

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv(r"C:\Users\prana\Recorded Course & Assignments\Project\Movie+Assignment+Data.csv")   # Write your code for importing the csv file here
movies.head()   # To check the first five columns of the dataframe.
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies.shape   # Checking the shape of the dataframe. It has 5043 rows and 28 columns.
# Out:
# (5043, 28)

# %%
movies.ndim   # This dataframe is 2 dimensional.
# Out:
# 2

# %%
movies.size  # The sizze of this dataframe(total number of elements) is 141204
# Out:
# 141204

# %%
movies.info()   
# Here using info() function we can see the datatype of all the columns and the non null values present in it.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
movies.describe()   
# describe() give us the statistical data of our dataframe( default is numerical data)
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movies.describe(include=["object"])
# describe(include=["object"]) give us the statistical data of our dataframe(for categorical data we use the above syntax)
# Out:
#         color     director_name    actor_2_name genres    actor_1_name  \
# count    5024              4939            5030   5043            5036
# unique      2              2398            3032    914            2097
# top     Color  Steven Spielberg  Morgan Freeman  Drama  Robert De Niro
# freq     4815                26              20    236              49
#
#        movie_title actor_3_name   plot_keywords  \
# count         5043         5020            4890
# unique        4917         3521            4760
# top       Ben-Hur    John Heard  based on novel
# freq             3            8               4
#
#                                           movie_imdb_link language country  \
# count                                                5043     5029    5038
# unique                                               4919       46      65
# top     http://www.imdb.com/title/tt0232500/?ref_=fn_t...  English     USA
# ...

# %%
movies.nunique()   
# nunique() tells us the unique number of values present in each column of our dataframe.
# Out:
# color                           2
# director_name                2398
# num_critic_for_reviews        528
# duration                      191
# director_facebook_likes       435
# actor_3_facebook_likes        906
# actor_2_name                 3032
# actor_1_facebook_likes        878
# gross                        4035
# genres                        914
# actor_1_name                 2097
# movie_title                  4917
# num_voted_users              4826
# cast_total_facebook_likes    3978
# actor_3_name                 3521
# facenumber_in_poster           19
# plot_keywords                4760
# movie_imdb_link              4919
# num_user_for_reviews          954
# language                       46
# country                        65
# content_rating                 18
# budget                        439
# title_year                     91
# actor_2_facebook_likes        917
# imdb_score                     78
# aspect_ratio                   22
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Rounding off the percentages upto two Decimal places
movies = movies.round(2)    # Used the round funtion to round off the the entire dataset upto 2 decimal points.
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# Write your code for column-wise null count here
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
movies.isnull().sum()# Write your code for row-wise null count here
movies.isnull().sum(axis = 1)      # sum(axis = 1) tells the kernel to execute the code for rows
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
# To get the percentage the formula is (part/total)*100
total_count= len(movies)        # To get total count
null_counts = movies.isnull().sum()     # To get total Null counts
null_percentages = round((null_counts/ total_count)*100, 2)    # Usinf the formula we can get the null percentages
null_percentages                                  # Calling null_percentages.
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.28
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
movies = movies.drop("color", axis = 1)
movies.head()
# Out:
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movies = movies.drop("director_facebook_likes", axis = 1)
movies.head()
# Out:
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     NaN       NaN
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
# 3                 23000.0    Christian Bale                 27000.0
# 4                     NaN        Rob Walker                   131.0
#
#          gross                           genres     actor_1_name  \
# 0  760505847.0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1  309404152.0         Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
movies = movies.drop(columns=["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"], axis = 1)
movies.head()
# Out:
#        director_name  num_critic_for_reviews  duration      actor_2_name  \
# 0      James Cameron                   723.0     178.0  Joel David Moore
# 1     Gore Verbinski                   302.0     169.0     Orlando Bloom
# 2         Sam Mendes                   602.0     148.0      Rory Kinnear
# 3  Christopher Nolan                   813.0     164.0    Christian Bale
# 4        Doug Walker                     NaN       NaN        Rob Walker
#
#          gross                           genres     actor_1_name  \
# 0  760505847.0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1  309404152.0         Action|Adventure|Fantasy      Johnny Depp
# 2  200074175.0        Action|Adventure|Thriller  Christoph Waltz
# 3  448130642.0                  Action|Thriller        Tom Hardy
# 4          NaN                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# ...

# %%
movies = movies.drop(columns=["actor_2_name","cast_total_facebook_likes","actor_3_name"], axis = 1)
movies.head()
# Out:
#        director_name  num_critic_for_reviews  duration        gross  \
# 0      James Cameron                   723.0     178.0  760505847.0
# 1     Gore Verbinski                   302.0     169.0  309404152.0
# 2         Sam Mendes                   602.0     148.0  200074175.0
# 3  Christopher Nolan                   813.0     164.0  448130642.0
# 4        Doug Walker                     NaN       NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# ...

# %%
movies = movies.drop(columns=["duration","facenumber_in_poster","content_rating","country","movie_imdb_link",
                              "aspect_ratio","plot_keywords"], axis = 1)
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# ...

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
movies = movies[~np.isnan(movies["gross"])]
movies = movies[~np.isnan(movies["budget"])]
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 5     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# ...

# %%
# Resetting index of the rows .
movies.reset_index(inplace =True, drop = True)
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# ...

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# Write your code for dropping the rows here
movies.isnull().sum(axis =1) > 5
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3886    False
# 3887    False
# 3888    False
# 3889    False
# 3890    False
# Length: 3891, dtype: bool

# %%
len(movies[movies.isnull().sum(axis =1) > 5])
# We got to know that there are no such rows where NaN values are more than 5.
# So we won't perform the dropping operation.
# Out:
# 0

# %% [markdown]
# - ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
movies["language"] = movies["language"].replace(np.nan, "English")
movies.isnull().sum()
# Rechecking if the language column has null values or not.
# Out:
# director_name             0
# num_critic_for_reviews    1
# gross                     0
# genres                    0
# actor_1_name              3
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  0
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 3886      Shane Carruth                   143.0     424760.0
# 3887   Neill Dela Llana                    35.0      70071.0
# 3888   Robert Rodriguez                    56.0    2040920.0
# 3889       Edward Burns                    14.0       4584.0
# 3890           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
print(len(movies.index))
# To check the number of rows retained
# Out:
# 3891

# %%
print(round((len(movies.index)/ 5043)*100,2))  # From above cell we got to know the current number of rows retained
# From cell number 259 we can see that before performing the operations, the number of rows were 5043.
# Out:
# 77.16

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
movies["budget"] = movies["budget"].apply(lambda x: round(x/1000000, 2))
movies["gross"] = movies["gross"].apply(lambda x: round(x/1000000, 2))
# Using apply() function to convert budget and gross from $ to million $
movies.head()
# Out:
#        director_name  num_critic_for_reviews   gross  \
# 0      James Cameron                   723.0  760.51
# 1     Gore Verbinski                   302.0  309.40
# 2         Sam Mendes                   602.0  200.07
# 3  Christopher Nolan                   813.0  448.13
# 4     Andrew Stanton                   462.0   73.06
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# ...

# %%
# Renaming both the columns (gross and budget) to avoid any confusion.
movies.rename(columns={"gross":"gross in million $", "budget":"budget in million $"}, inplace= True)
# Thus it will be easier to understand that the columns have been converted to million $.
movies.head()
# Out:
#        director_name  num_critic_for_reviews  gross in million $  \
# 0      James Cameron                   723.0              760.51
# 1     Gore Verbinski                   302.0              309.40
# 2         Sam Mendes                   602.0              200.07
# 3  Christopher Nolan                   813.0              448.13
# 4     Andrew Stanton                   462.0               73.06
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# ...

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
movies["profit"] = movies["gross in million $"]-movies["budget in million $"]
# We will get the profit by getting the difference of the two columns "gross" and "budget"
movies.head()
# Out:
#        director_name  num_critic_for_reviews  gross in million $  \
# 0      James Cameron                   723.0              760.51
# 1     Gore Verbinski                   302.0              309.40
# 2         Sam Mendes                   602.0              200.07
# 3  Christopher Nolan                   813.0              448.13
# 4     Andrew Stanton                   462.0               73.06
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# ...

# %%
# Write your code for sorting the dataframe here
movies = movies.sort_values(by="profit", ascending = False)

# %%
# Write your code to get the top 10 profiting movies here
top10 = pd.DataFrame(movies.head(10))
top10
# Out:
#           director_name  num_critic_for_reviews  gross in million $  \
# 0         James Cameron                   723.0              760.51
# 28      Colin Trevorrow                   644.0              652.18
# 25        James Cameron                   315.0              658.67
# 2726       George Lucas                   282.0              460.94
# 2770   Steven Spielberg                   215.0              434.95
# 758         Joss Whedon                   703.0              623.28
# 16          Joss Whedon                   703.0              623.28
# 487        Roger Allers                   186.0              422.78
# 232        George Lucas                   320.0              474.54
# 64    Christopher Nolan                   645.0              533.32
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %% [markdown]
# - ##### Avatar Movie has the highest profit of all the movies.

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`.

# %%
# Write your code for dropping duplicate values here
movies = movies.drop_duplicates()

# %%
# Write code for repeating subtask 2 here

# Write your code for sorting the dataframe here
movies = movies.sort_values(by="profit", ascending = False)

# Write your code to get the top 10 profiting movies here
top10 = pd.DataFrame(movies.head(10))
top10
# Out:
#           director_name  num_critic_for_reviews  gross in million $  \
# 0         James Cameron                   723.0              760.51
# 28      Colin Trevorrow                   644.0              652.18
# 25        James Cameron                   315.0              658.67
# 2726       George Lucas                   282.0              460.94
# 2770   Steven Spielberg                   215.0              434.95
# 758         Joss Whedon                   703.0              623.28
# 487        Roger Allers                   186.0              422.78
# 232        George Lucas                   320.0              474.54
# 64    Christopher Nolan                   645.0              533.32
# 424           Gary Ross                   673.0              408.00
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
IMDb_Top_250 = pd.DataFrame(movies[movies.num_voted_users>25000].sort_values(by = "imdb_score", ascending = False)).head(250)
#Created new dataframe using the given conditions and sorting them in descending order by using the column "imdb_score".
#Giving head as 250 as we need to create a dataframe of 250 movies.
IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews  gross in million $  \
# 1806        Frank Darabont                   199.0               28.34
# 3041  Francis Ford Coppola                   208.0              134.82
# 2564  Francis Ford Coppola                   149.0               57.30
# 64       Christopher Nolan                   645.0              533.32
# 328          Peter Jackson                   328.0              377.02
# ...                    ...                     ...                 ...
# 3708       Cristian Mungiu                   233.0                1.19
# 2279        John Carpenter                   318.0               47.00
# 3804        John Carpenter                   318.0               47.00
# 2730      David O. Russell                   410.0               93.57
# 613           Michael Mann                   209.0               28.97
#
#                               genres      actor_1_name  \
# 1806                     Crime|Drama    Morgan Freeman
# ...

# %%
# Adding Rank column
IMDb_Top_250["Rank"] = range(1, 1+len(IMDb_Top_250))
#Creating a new column using range() funtion of pandas where (1:(start), 1=len(IMDb_Top_250):(length of the dataframe, ie. 250)) are the arguments.
IMDb_Top_250.head()
# Out:
#              director_name  num_critic_for_reviews  gross in million $  \
# 1806        Frank Darabont                   199.0               28.34
# 3041  Francis Ford Coppola                   208.0              134.82
# 2564  Francis Ford Coppola                   149.0               57.30
# 64       Christopher Nolan                   645.0              533.32
# 328          Peter Jackson                   328.0              377.02
#
#                               genres    actor_1_name  \
# 1806                     Crime|Drama  Morgan Freeman
# 3041                     Crime|Drama       Al Pacino
# 2564                     Crime|Drama  Robert De Niro
# 64       Action|Crime|Drama|Thriller  Christian Bale
# 328   Action|Adventure|Drama|Fantasy   Orlando Bloom
#
#                                          movie_title  num_voted_users  \
# 1806                       The Shawshank Redemption           1689764
# 3041                                  The Godfather           1155770
# ...

# %%
Top_Foreign_Lang_Film = IMDb_Top_250.loc[IMDb_Top_250["language" ] != "English"]  
# Using the loc attribute to extract movies other than "English" language.
Top_Foreign_Lang_Film.head(10)
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
# Out:
#                          director_name  num_critic_for_reviews  \
# 3638                      Sergio Leone                   181.0
# 3406                Fernando Meirelles                   214.0
# 3768                    Akira Kurosawa                   153.0
# 2183                    Hayao Miyazaki                   246.0
# 3844                      Majid Majidi                    46.0
# 3525  Florian Henckel von Donnersmarck                   215.0
# 1259                    S.S. Rajamouli                    44.0
# 3718                    Asghar Farhadi                   354.0
# 1231                Jean-Pierre Jeunet                   242.0
# 3449                    Chan-wook Park                   305.0
#
#       gross in million $                              genres  \
# 3638                6.10                             Western
# 3406                7.56                         Crime|Drama
# 3768                0.27              Action|Adventure|Drama
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %%
is_present = Top_Foreign_Lang_Film.isin(["Veer-Zaara"]).any().any()      
# Using isin() function to check if "Veer_Zaara" is present in dataframe or not followed by any() mentioning that if it is present in any of the column.
is_present
# Out:
# False

# %% [markdown]
# We can't Spot Veer-Zaara in the dataframe

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
# Write your code for extracting the top 10 directors here
movies_made_by_director = movies.groupby("director_name")       
# Using groupby() function to group the names of directors in a column

# %%
# Creating a dataframe top10director based on imdb_score
top10director = pd.DataFrame(movies_made_by_director.imdb_score.mean().sort_values(ascending = False).head(10))
top10director
# Out:
#                        imdb_score
# director_name
# Charles Chaplin          8.600000
# Tony Kaye                8.600000
# Alfred Hitchcock         8.500000
# Ron Fricke               8.500000
# Damien Chazelle          8.500000
# Majid Majidi             8.500000
# Sergio Leone             8.433333
# Christopher Nolan        8.425000
# S.S. Rajamouli           8.400000
# Marius A. Markevicius    8.400000

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
movies["genre_1"] = movies["genres"].apply(lambda x: x.split("|")[0])
movies["genre_2"] = movies["genres"].apply(lambda x: x.split("|")[1] if len(x.split("|")) > 1 else x.split("|")[0])
# Here we used a condition realising that there can be only one genre of a certain movie.
movies.head(10)
# Out:
#           director_name  num_critic_for_reviews  gross in million $  \
# 0         James Cameron                   723.0              760.51
# 28      Colin Trevorrow                   644.0              652.18
# 25        James Cameron                   315.0              658.67
# 2726       George Lucas                   282.0              460.94
# 2770   Steven Spielberg                   215.0              434.95
# 758         Joss Whedon                   703.0              623.28
# 487        Roger Allers                   186.0              422.78
# 232        George Lucas                   320.0              474.54
# 64    Christopher Nolan                   645.0              533.32
# 424           Gary Ross                   673.0              408.00
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
movies_by_segment =  movies.groupby(["genre_1","genre_2"])   # Using a groupby() function
movies_by_segment
# Write your code for grouping the dataframe here

# %%
PopGenre = pd.DataFrame(movies_by_segment["gross in million $"].mean().sort_values(ascending = False).head())
# creating a dataframe to using the "gross in million $" column by taking it's mean and sorting it in descending order.
PopGenre
# Write your code for getting the 5 most popular combo of genres here
# Out:
#                      gross in million $
# genre_1   genre_2
# Family    Sci-Fi             434.950000
# Adventure Sci-Fi             228.628750
#           Family             118.918824
#           Animation          116.998462
# Action    Adventure          109.595510

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# Write your code for creating three new dataframes here

Meryl_Streep = pd.DataFrame(movies.loc[movies.actor_1_name == "Meryl Streep"])
Meryl_Streep.head()
# Include all movies in which Meryl_Streep is the lead
# Out:
#        director_name  num_critic_for_reviews  gross in million $  \
# 1332   David Frankel                   208.0              124.73
# 1482  Sydney Pollack                    66.0               87.10
# 1140     Nora Ephron                   252.0               94.13
# 1525   David Frankel                   234.0               63.54
# 397     Nancy Meyers                   187.0              112.70
#
#                        genres  actor_1_name             movie_title  \
# 1332     Comedy|Drama|Romance  Meryl Streep  The Devil Wears Prada
# 1482  Biography|Drama|Romance  Meryl Streep          Out of Africa
# 1140  Biography|Drama|Romance  Meryl Streep          Julie & Julia
# 1525     Comedy|Drama|Romance  Meryl Streep           Hope Springs
# 397      Comedy|Drama|Romance  Meryl Streep       It's Complicated
#
#       num_voted_users  num_user_for_reviews language  budget in million $  \
# 1332           286178                 631.0  English                 35.0
# ...

# %%
Leo_Caprio = pd.DataFrame(movies.loc[movies.actor_1_name == "Leonardo DiCaprio"])
Leo_Caprio.head()
# Include all movies in which Leo_Caprio is the lead
# Out:
#              director_name  num_critic_for_reviews  gross in million $  \
# 25           James Cameron                   315.0              658.67
# 94       Christopher Nolan                   642.0              292.57
# 867       Steven Spielberg                   194.0              164.44
# 285      Quentin Tarantino                   765.0              162.80
# 174  Alejandro G. Iñárritu                   556.0              183.64
#
#                                genres       actor_1_name  \
# 25                      Drama|Romance  Leonardo DiCaprio
# 94   Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio
# 867             Biography|Crime|Drama  Leonardo DiCaprio
# 285                     Drama|Western  Leonardo DiCaprio
# 174  Adventure|Drama|Thriller|Western  Leonardo DiCaprio
#
#               movie_title  num_voted_users  num_user_for_reviews language  \
# 25               Titanic            793059                2528.0  English
# ...

# %%
Brad_Pitt = pd.DataFrame(movies.loc[movies.actor_1_name == "Brad Pitt"])
Brad_Pitt.head()
# Include all movies in which Brad_Pitt is the lead
# Out:
#          director_name  num_critic_for_reviews  gross in million $  \
# 388  Steven Soderbergh                   186.0              183.41
# 246         Doug Liman                   233.0              186.34
# 895        Neil Jordan                   120.0              105.26
# 453         David Ayer                   406.0               85.71
# 245  Steven Soderbergh                   198.0              125.53
#
#                                    genres actor_1_name  \
# 388                        Crime|Thriller    Brad Pitt
# 246  Action|Comedy|Crime|Romance|Thriller    Brad Pitt
# 895                  Drama|Fantasy|Horror    Brad Pitt
# 453                      Action|Drama|War    Brad Pitt
# 245                        Crime|Thriller    Brad Pitt
#
#                                            movie_title  num_voted_users  \
# 388                                    Ocean's Eleven            402645
# 246                                  Mr. & Mrs. Smith            348861
# ...

# %%
# Write your code for combining the three dataframes here
Combined = pd.concat([Meryl_Streep,Leo_Caprio,Brad_Pitt], axis=0)  # Using a concat() function of pandas here to combine all the dataframes
Combined
# Out:
#               director_name  num_critic_for_reviews  gross in million $  \
# 1332          David Frankel                   208.0              124.73
# 1482         Sydney Pollack                    66.0               87.10
# 1140            Nora Ephron                   252.0               94.13
# 1525          David Frankel                   234.0               63.54
# 397            Nancy Meyers                   187.0              112.70
# 2520         Phyllida Lloyd                   331.0               29.96
# 1795         Stephen Daldry                   174.0               41.60
# 2816          Robert Altman                   211.0               20.34
# 1046          Curtis Hanson                    42.0               46.82
# 1574          Carl Franklin                    64.0               23.21
# 1401         Robert Redford                   227.0               15.00
# 25            James Cameron                   315.0              658.67
# ...

# %%
# Write your code for grouping the combined dataframe here
combined_df = Combined.groupby("actor_1_name")
combined_df

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
mean_of_critic = combined_df[["num_critic_for_reviews","num_user_for_reviews"]].mean()
mean_of_critic
# Out:
#                    num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Brad Pitt                      245.000000            742.352941
# Leonardo DiCaprio              330.190476            914.476190
# Meryl Streep                   181.454545            297.181818

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!
